# %% [markdown]
# #**Importacion de datos**

# %%
import pandas as pd

# %%
url_1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url_2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url_3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url_4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda_1 = pd.read_csv(url_1)
tienda_2 = pd.read_csv(url_2)
tienda_3 = pd.read_csv(url_3)
tienda_4 = pd.read_csv(url_4)

# %%
tienda_4.sample(5)
# Out:
#                      Producto  Categoría del Producto    Precio  \
# 858         Guitarra acústica  Instrumentos musicales  246100.0
# 12    Dashboards con Power BI                  Libros   36000.0
# 1186               Smartwatch            Electrónicos  163300.0
# 394                Microondas       Electrodomésticos  331600.0
# 2280           Dinosaurio Rex                Juguetes   21800.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 858          11300.0      16/04/2020  Mariana Herrera        Riohacha
# 12            9800.0      21/11/2020   Blanca Ramirez          Bogotá
# 1186          9100.0      16/12/2020  Izabela de León          Bogotá
# 394          15800.0      10/06/2020    Rafael Acosta       Cartagena
# 2280             0.0      26/02/2020    Lucas Olivera        Medellín
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 858              1               Nequi                   1  11.54444 -72.90722
# ...

# %% [markdown]
# #**Análisis de datos**

# %% [markdown]
# ##**Ingreso total por tiendas**

# %% [markdown]
# ###**Ingreso de la tienda 1**

# %%
ingreso_total_tienda_1 = sum(tienda_1["Precio"])
ingreso_total_tienda_1
# Out:
# 1150880400.0

# %%
print(f'La tienda 1 obtuvo como ingresos $ {int(ingreso_total_tienda_1)} COP ')
# Out:
# La tienda 1 obtuvo como ingresos $ 1150880400 COP

# %% [markdown]
# ###**Ingreso de la tienda 2**

# %%
ingreso_total_tienda_2 = sum(tienda_2["Precio"])
ingreso_total_tienda_2
# Out:
# 1116343500.0

# %%
print(f'La tienda 2 obtuvo como ingresos $ {int(ingreso_total_tienda_2)} COP ')
# Out:
# La tienda 2 obtuvo como ingresos $ 1116343500 COP

# %% [markdown]
# ###**Ingreso de la tienda 3**

# %%
ingreso_total_tienda_3 = sum(tienda_3["Precio"])
ingreso_total_tienda_3
# Out:
# 1098019600.0

# %%
print(f'La tienda 3 obtuvo como ingresos $ {int(ingreso_total_tienda_3)} COP ')
# Out:
# La tienda 3 obtuvo como ingresos $ 1098019600 COP

# %% [markdown]
# ###**Ingreso de la tienda 4**

# %%
ingreso_total_tienda_4 = sum(tienda_4["Precio"])
ingreso_total_tienda_4
# Out:
# 1038375700.0

# %%
print(f'La tienda 4 obtuvo como ingresos $ {int(ingreso_total_tienda_4)} COP')
# Out:
# La tienda 4 obtuvo como ingresos $ 1038375700 COP

# %% [markdown]
# ##**Comparación de ingresos de tiendas**

# %%
ingresos_tiendas = {"Nombre tienda": ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4" ],
                       "Ingresos": [ingreso_total_tienda_1, ingreso_total_tienda_2, ingreso_total_tienda_3, ingreso_total_tienda_4]}
df_ingresos_tiendas = pd.DataFrame(ingresos_tiendas)
df_ingresos_tiendas.sort_values(by="Ingresos", ascending=True)
# Out:
#   Nombre tienda      Ingresos
# 3      Tienda 4  1.038376e+09
# 2      Tienda 3  1.098020e+09
# 1      Tienda 2  1.116344e+09
# 0      Tienda 1  1.150880e+09

# %% [markdown]
# ###**Tienda con mayor ingresos**

# %%
maximo = max(df_ingresos_tiendas['Ingresos'])
valor_maximo = df_ingresos_tiendas.loc[df_ingresos_tiendas['Ingresos'] == maximo]
valor_maximo
# Out:
#   Nombre tienda      Ingresos
# 0      Tienda 1  1.150880e+09

# %% [markdown]
# ###**Tienda con menores ingresos**

# %%
minimo = min(df_ingresos_tiendas['Ingresos'])
valor_minimo = df_ingresos_tiendas.loc[df_ingresos_tiendas['Ingresos'] == minimo]
valor_minimo
# Out:
#   Nombre tienda      Ingresos
# 3      Tienda 4  1.038376e+09

# %% [markdown]
# ##**Ingreso de ventas por categoría**

# %% [markdown]
# ###**Ingresos Tienda 1**

# %%
df_agrupado_tienda_1 = tienda_1.groupby("Categoría del Producto").sum("Precio")
df_agrupado_tienda_1 = df_agrupado_tienda_1["Precio"]
df_agrupado_tienda_1
# Out:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64

# %% [markdown]
# ###**Ingresos Tienda 2**

# %%
df_agrupado_tienda_2 = tienda_2.groupby("Categoría del Producto").sum("Precio")
df_agrupado_tienda_2 = df_agrupado_tienda_2["Precio"]
df_agrupado_tienda_2
# Out:
# Categoría del Producto
# Artículos para el hogar     14746900.0
# Deportes y diversión        34744500.0
# Electrodomésticos          348567800.0
# Electrónicos               410831100.0
# Instrumentos musicales     104990300.0
# Juguetes                    15945400.0
# Libros                      10091200.0
# Muebles                    176426300.0
# Name: Precio, dtype: float64

# %% [markdown]
# ###**Ingresos Tienda 3**

# %%
df_agrupado_tienda_3 = tienda_3.groupby("Categoría del Producto").sum("Precio")
df_agrupado_tienda_3 = df_agrupado_tienda_3["Precio"]
df_agrupado_tienda_3
# Out:
# Categoría del Producto
# Artículos para el hogar     15060000.0
# Deportes y diversión        35593100.0
# Electrodomésticos          329237900.0
# Electrónicos               410775800.0
# Instrumentos musicales      77380900.0
# Juguetes                    19401100.0
# Libros                       9498700.0
# Muebles                    201072100.0
# Name: Precio, dtype: float64

# %% [markdown]
# ###**Ingresos Tienda 4**

# %%
df_agrupado_tienda_4 = tienda_4.groupby("Categoría del Producto").sum("Precio")
df_agrupado_tienda_4 = df_agrupado_tienda_4["Precio"]
df_agrupado_tienda_4
# Out:
# Categoría del Producto
# Artículos para el hogar     15074500.0
# Deportes y diversión        33350100.0
# Electrodomésticos          283260200.0
# Electrónicos               409476100.0
# Instrumentos musicales      75102400.0
# Juguetes                    20262200.0
# Libros                       9321300.0
# Muebles                    192528900.0
# Name: Precio, dtype: float64

# %% [markdown]
# ##**Número de ventas por categoría**

# %% [markdown]
# ###**Ventas Tienda 1**

# %%
numero_ventas_categoria_tienda_1 = tienda_1.groupby("Categoría del Producto").size()
numero_ventas_categoria_tienda_1.sort_values()
# Out:
# Categoría del Producto
# Artículos para el hogar    171
# Libros                     173
# Instrumentos musicales     182
# Deportes y diversión       284
# Electrodomésticos          312
# Juguetes                   324
# Electrónicos               448
# Muebles                    465
# dtype: int64

# %% [markdown]
# ###**Ventas Tienda 2**

# %%
numero_ventas_categoria_tienda_2 = tienda_2.groupby("Categoría del Producto").size()
numero_ventas_categoria_tienda_2.sort_values()
# Out:
# Categoría del Producto
# Artículos para el hogar    181
# Libros                     197
# Instrumentos musicales     224
# Deportes y diversión       275
# Electrodomésticos          305
# Juguetes                   313
# Electrónicos               422
# Muebles                    442
# dtype: int64

# %% [markdown]
# ###**Ventas Tienda 3**

# %%
numero_ventas_categoria_tienda_3 = tienda_3.groupby("Categoría del Producto").size()
numero_ventas_categoria_tienda_3.sort_values()
# Out:
# Categoría del Producto
# Artículos para el hogar    177
# Instrumentos musicales     177
# Libros                     185
# Deportes y diversión       277
# Electrodomésticos          278
# Juguetes                   315
# Electrónicos               451
# Muebles                    499
# dtype: int64

# %% [markdown]
# ###**Ventas Tienda 4**

# %%
numero_ventas_categoria_tienda_4 = tienda_4.groupby("Categoría del Producto").size()
numero_ventas_categoria_tienda_4.sort_values()
# Out:
# Categoría del Producto
# Instrumentos musicales     170
# Libros                     187
# Artículos para el hogar    201
# Electrodomésticos          254
# Deportes y diversión       277
# Juguetes                   338
# Electrónicos               451
# Muebles                    480
# dtype: int64

# %% [markdown]
# ##**Valoración media por tienda**

# %% [markdown]
# ###**Valoración Tienda 1**

# %%
valoracion_media_1 = tienda_1["Calificación"].mean()
valoracion_media_1
print(f'La valoración media de la tienda 1 es de {valoracion_media_1:.2f} estrellas')
# Out:
# La valoración media de la tienda 1 es de 3.98 estrellas

# %% [markdown]
# ###**Valoración Tienda 2**

# %%
valoracion_media_2 = tienda_2["Calificación"].mean()
valoracion_media_2
print(f'La valoración media de la tienda 2 es de {valoracion_media_2:.2f} estrellas')
# Out:
# La valoración media de la tienda 2 es de 4.04 estrellas

# %% [markdown]
# ###**Valoración Tienda 3**

# %%
valoracion_media_3 = tienda_3["Calificación"].mean()
valoracion_media_3
print(f'La valoración media de la tienda 3 es de {valoracion_media_3:.2f} estrellas')
# Out:
# La valoración media de la tienda 3 es de 4.05 estrellas

# %% [markdown]
# ###**Valoración Tienda 4**

# %%
valoracion_media_4 = tienda_4["Calificación"].mean()
valoracion_media_4
print(f'La valoración media de la tienda 4 es de {valoracion_media_4:.2f} estrellas')
# Out:
# La valoración media de la tienda 4 es de 4.00 estrellas

# %% [markdown]
# ##**Productos más  y menos vendidos**

# %% [markdown]
# ###**Tienda 1**

# %%
df_productos_tienda_1 = tienda_1.groupby("Producto").size()
df_productos_tienda_1.sort_values(ascending=True)
# Out:
# Producto
# Auriculares con micrófono      33
# Celular ABXY                   33
# Olla de presión                35
# Pandereta                      36
# Ciencia de datos con Python    39
# Mochila                        39
# Dinosaurio Rex                 40
# Asistente virtual              40
# Muñeca bebé                    40
# Mesa de comedor                40
# Cuerda para saltar             40
# Sillón                         41
# Set de vasos                   41
# Iniciando en programación      41
# Balón de voleibol              42
# Dashboards con Power BI        42
# Tablet ABXY                    42
# Set de ollas                   43
# Juego de mesa                  43
# Smartwatch                     43
# Cubo mágico 8x8                44
# Cama king                      44
# Smart TV                       44
# Kit de bancas                  44
# Cama box                       44
# Mesa de centro                 44
# Estufa                         45
# ...

# %% [markdown]
# ####**Productos más vendidos**

# %%
valor_producto_mas_vendido_1 = max(df_productos_tienda_1)
producto_mas_vendido_1 = df_productos_tienda_1[df_productos_tienda_1 == valor_producto_mas_vendido_1]
print(f'El producto más vendido fue el {producto_mas_vendido_1} por {valor_producto_mas_vendido_1}')
# Out:
# El producto más vendido fue el Producto
# Armario          60
# Microondas       60
# TV LED UHD 4K    60
# dtype: int64 por 60

# %% [markdown]
# ####**Productos menos vendidos**

# %%
valor_producto_menos_vendido_1 = min(df_productos_tienda_1)
producto_menos_vendido_1 = df_productos_tienda_1[df_productos_tienda_1 == valor_producto_menos_vendido_1]
print(f'El producto menos vendido fue el {producto_menos_vendido_1} por {valor_producto_menos_vendido_1}')
# Out:
# El producto menos vendido fue el Producto
# Auriculares con micrófono    33
# Celular ABXY                 33
# dtype: int64 por 33

# %% [markdown]
# ###**Tienda 2**

# %%
df_productos_tienda_2 = tienda_2.groupby("Producto").size()
df_productos_tienda_2.sort_values(ascending=True)
# Out:
# Producto
# Juego de mesa                  32
# Impresora                      34
# Mesa de comedor                34
# Sillón                         35
# Auriculares                    37
# Asistente virtual              38
# Cubertería                     39
# Smart TV                       40
# Celular ABXY                   41
# Estufa                         42
# Dinosaurio Rex                 42
# Balón de baloncesto            42
# Dashboards con Power BI        43
# Ciencia de datos con Python    43
# Auriculares con micrófono      44
# Mesa de noche                  44
# Olla de presión                44
# Tablet ABXY                    44
# Sofá reclinable                44
# Smartwatch                     44
# Kit de bancas                  45
# Bicicleta                      45
# Cama king                      45
# TV LED UHD 4K                  45
# Mochila                        45
# Mesa de centro                 45
# Cubo mágico 8x8                45
# ...

# %% [markdown]
# ####**Productos más vendidos**

# %%
valor_producto_mas_vendido_2 = max(df_productos_tienda_2)
producto_mas_vendido_2 = df_productos_tienda_2[df_productos_tienda_2 == valor_producto_mas_vendido_2]
print(f'El producto más vendido fue el {producto_mas_vendido_2} por {valor_producto_mas_vendido_2}')
# Out:
# El producto más vendido fue el Producto
# Iniciando en programación    65
# dtype: int64 por 65

# %% [markdown]
# ####**Productos menos vendidos**

# %%
valor_producto_menos_vendido_2 = min(df_productos_tienda_2)
producto_menos_vendido_2 = df_productos_tienda_2[df_productos_tienda_2 == valor_producto_menos_vendido_2]
print(f'El producto menos vendido fue el {producto_menos_vendido_2} por {valor_producto_menos_vendido_2}')
# Out:
# El producto menos vendido fue el Producto
# Juego de mesa    32
# dtype: int64 por 32

# %% [markdown]
# ###**Tienda 3**

# %%
df_productos_tienda_3 = tienda_3.groupby("Producto").size()
df_productos_tienda_3.sort_values(ascending=True)
# Out:
# Producto
# Bloques de construcción        35
# Set de vasos                   36
# Mochila                        36
# Microondas                     36
# Vaso térmico                   38
# Guitarra eléctrica             38
# Cubertería                     39
# Asistente virtual              39
# Auriculares con micrófono      39
# Muñeca bebé                    39
# Dashboards con Power BI        40
# Batería                        41
# Mesa de centro                 42
# Lavadora de ropa               42
# TV LED UHD 4K                  42
# Auriculares                    43
# Celular ABXY                   44
# Cubo mágico 8x8                44
# Sofá reclinable                45
# Secadora de ropa               45
# Ciencia de datos con Python    46
# Iphone 15                      46
# Smartwatch                     46
# Silla de oficina               46
# Dinosaurio Rex                 46
# Cama box                       46
# Iniciando en programación      46
# ...

# %% [markdown]
# ####**Productos más vendidos**

# %%
valor_producto_mas_vendido_3 = max(df_productos_tienda_3)
producto_mas_vendido_3 = df_productos_tienda_3[df_productos_tienda_3 == valor_producto_mas_vendido_3]
print(f'El producto más vendido fue el {producto_mas_vendido_3} por {valor_producto_mas_vendido_3}')
# Out:
# El producto más vendido fue el Producto
# Kit de bancas    57
# dtype: int64 por 57

# %% [markdown]
# ####**Productos menos vendidos**

# %%
valor_producto_menos_vendido_3 = min(df_productos_tienda_3)
producto_menos_vendido_3 = df_productos_tienda_3[df_productos_tienda_3 == valor_producto_menos_vendido_3]
print(f'El producto menos vendido fue el {producto_menos_vendido_3} por {valor_producto_menos_vendido_3}')
# Out:
# El producto menos vendido fue el Producto
# Bloques de construcción    35
# dtype: int64 por 35

# %% [markdown]
# ###**Tienda 4**
# **Productos más vendidos**

# %%
df_productos_tienda_4 = tienda_4.groupby("Producto").size()
df_productos_tienda_4.sort_values(ascending=True)
# Out:
# Producto
# Guitarra eléctrica             33
# Armario                        34
# Guitarra acústica              37
# Ciencia de datos con Python    38
# Lavadora de ropa               38
# Refrigerador                   38
# Ajedrez de madera              39
# Celular ABXY                   39
# Smartwatch                     39
# Secadora de ropa               40
# Silla de oficina               40
# TV LED UHD 4K                  40
# Kit de bancas                  42
# Auriculares con micrófono      42
# Lavavajillas                   43
# Cuerda para saltar             43
# Mochila                        43
# Iniciando en programación      43
# Mesa de centro                 44
# Auriculares                    44
# Sillón                         45
# Tablet ABXY                    45
# Bicicleta                      45
# Olla de presión                46
# Set de vasos                   46
# Estufa                         47
# Dinosaurio Rex                 47
# ...

# %% [markdown]
# ####**Productos más vendidos**

# %%
valor_producto_mas_vendido_4 = max(df_productos_tienda_4)
producto_mas_vendido_4 = df_productos_tienda_4[df_productos_tienda_4 == valor_producto_mas_vendido_4]
print(f'El producto más vendido fue el {producto_mas_vendido_4} por {valor_producto_mas_vendido_4}')
# Out:
# El producto más vendido fue el Producto
# Cama box    62
# dtype: int64 por 62

# %% [markdown]
# ####**Productos menos vendidos**

# %%
valor_producto_menos_vendido_4 = min(df_productos_tienda_4)
producto_menos_vendido_4 = df_productos_tienda_4[df_productos_tienda_4 == valor_producto_menos_vendido_4]
print(f'El producto menos vendido fue el {producto_menos_vendido_4} por {valor_producto_menos_vendido_4}')
# Out:
# El producto menos vendido fue el Producto
# Guitarra eléctrica    33
# dtype: int64 por 33

# %% [markdown]
# ##**Valor promedio de Flete**

# %% [markdown]
# ###**Promedio Tienda 1**

# %%
promedio_flete_tienda_1 = tienda_1['Costo de envío'].mean(skipna=True)
print(f'El costo de envío promedio de la tienda 1 es ${int(promedio_flete_tienda_1)} COP')
# Out:
# El costo de envío promedio de la tienda 1 es $26018 COP

# %% [markdown]
# ###**Promedio Tienda 2**

# %%
promedio_flete_tienda_2 = tienda_2['Costo de envío'].mean(skipna=True)
print(f'El costo de envío promedio de la tienda 2 es ${int(promedio_flete_tienda_2)} COP')
# Out:
# El costo de envío promedio de la tienda 2 es $25216 COP

# %% [markdown]
# ###**Promedio Tienda 3**

# %%
promedio_flete_tienda_3 = tienda_3['Costo de envío'].mean(skipna=True)
print(f'El costo de envío promedio de la tienda 3 es ${int(promedio_flete_tienda_3)} COP')
# Out:
# El costo de envío promedio de la tienda 3 es $24805 COP

# %% [markdown]
# ###**Promedio Tienda 4**

# %%
promedio_flete_tienda_4 = tienda_4['Costo de envío'].mean(skipna=True)
print(f'El costo de envío promedio de la tienda 4 es ${int(promedio_flete_tienda_4)} COP')
# Out:
# El costo de envío promedio de la tienda 4 es $23459 COP

# %% [markdown]
# #**Visualización**
